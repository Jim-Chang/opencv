# %%
class PicoMotor:
    
    _MIN_SPEED = 50
    _MAX_SPEED = 100
    _MIN_DIFF = 10
    
    def __init__(self, serial_port):
        self.serial_port = serial_port
        
    def _send(self, left, right):
        cmd = f'MOTOR:left:{left}:right:{right}'.encode()
        serial_port.write(cmd)
        
    def _bounding_speed(self, speed):
        if speed == 0:
            return speed
        
        if abs(speed) < self._MIN_SPEED:
            print(f'[PicoMotor]: Lowest speed is {self._MIN_SPEED}, reset value {speed} to it.')
            return self._MIN_SPEED if speed > 0 else -self._MIN_SPEED
        
        if abs(speed) > self._MAX_SPEED:
            print(f'[PicoMotor]: Max speed is {self._MAX_SPEED}, reset value {speed} to it.')
            return self._MAX_SPEED if speed > 0 else -self._MAX_SPEED
        
        return speed
    
    def _get_diff_speed(self, speed, diff):
        if speed >= 0:
            return speed - diff
        
        return speed + diff
    
    def _is_need_change_to_rotate(self, speed, diff_speed):
        return abs(speed) == self._MIN_SPEED or (abs(speed) - abs(diff_speed)) < self._MIN_DIFF
        
    def go(self, speed, diff):
        '''
        high level，會依照 speed, diff 的值來決定要 直走 還是 轉彎
        speed:
            + : forward
            - : backward
        diff:
            + : right
            - : left
        '''
        if diff == 0:
            return self.go_straight(speed)
        
        return self.go_turn(speed, diff)
        
    def go_straight(self, speed):
        '''
        Always 直走
        speed:
            + : forward
            - : backward
        '''
        print(f'[PicoMotor]: go_straight, speed={speed}')
        speed = self._bounding_speed(speed)
        self._send(speed, speed)
        
    def go_turn(self, speed, diff):
        '''
        轉彎專用
        speed:
            + : forward
            - : backward
        diff:
            + : right
            - : left
        '''
        print(f'[PicoMotor]: go_turn, speed={speed}, diff={diff}')
        if speed == 0:
            return
        
        speed = self._bounding_speed(speed)
        diff_speed = self._bounding_speed(self._get_diff_speed(speed, abs(diff)))
        
        if self._is_need_change_to_rotate(speed, diff_speed):
            if (speed > 0 and diff >= 0) or (speed < 0 and diff < 0):
                print('[PicoMotor]: change to right_rotate')
                self.right_rotate()
            else:
                print('[PicoMotor]: change to left_rotate')
                self.left_rotate()
        else:    
            if diff >= 0:
                self._send(speed, diff_speed)
            else:
                self._send(diff_speed, speed)

    def turn_left(self, speed, diff):
        '''
        明確左轉使用
        speed: 
            + : forward
            - : backward
        diff:
            always +
        '''
        print(f'[PicoMotor]: turn_left, speed={speed}, diff={diff}')
        return self.go_turn(speed, -diff)

    def turn_right(self, speed, diff):
        '''
        明確右轉使用
        speed: 
            + : forward
            - : backward
        diff:
            always +
        '''
        print(f'[PicoMotor]: turn_tight, speed={speed}, diff={diff}')
        return self.go_turn(speed, diff)

    def left_rotate(self):
        '''
        原地向左旋轉
        '''
        print(f'[PicoMotor]: left_rotate')
        self._send(-self._MIN_SPEED, self._MIN_SPEED)
        
    def right_rotate(self):
        '''
        原地向右旋轉
        '''
        print(f'[PicoMotor]: right_rotate')     
        self._send(self._MIN_SPEED, -self._MIN_SPEED)
        
    def stop(self):
        self._send(0, 0)

# %%
import serial

_DEFAULT_PORT = '/dev/ttyTHS1'
_BAUDRATE = 115200

serial_port = serial.Serial(
    port=port,
    baudrate=_BAUDRATE,
    bytesize=serial.EIGHTBITS,
    parity=serial.PARITY_NONE,
    stopbits=serial.STOPBITS_ONE,
)

# %%
class FakeSerial:
    def write(self, cmd):
        print(f'[FakeSerial]: {cmd}')
        
serial_port = FakeSerial()

# %%
m = PicoMotor(serial_port)
print('==== Test forward ====')
m.go_straight(100)
m.go_straight(60)
m.go_straight(20)
print('\n==== Test backward ====')
m.go_straight(-100)
m.go_straight(-60)
m.go_straight(-20)
print('\n==== Test left ====')
m.turn_left(100, 10)
m.turn_left(60, 10)
m.turn_left(60, 20)
m.turn_left(50, 10)
m.turn_left(59, 10)
m.turn_left(30, 10)
print('\n==== Test left ====')
m.go_turn(100, -10)
m.go_turn(60, -10)
m.go_turn(60, -20)
m.go_turn(50, -10)
m.go_turn(59, -10)
m.go_turn(30, -10)
print('\n==== Test right ====')
m.turn_right(100, 10)
m.turn_right(60, 10)
m.turn_right(60, 20)
m.turn_right(50, 10)
m.turn_right(59, 10)
m.turn_right(30, 10)
print('\n==== Test right ====')
m.go_turn(100, 10)
m.go_turn(60, 10)
m.go_turn(60, 20)
m.go_turn(50, 10)
m.go_turn(59, 10)
m.go_turn(30, 10)
# Out:
# ==== Test forward ====
# [PicoMotor]: go_straight, speed=100
# [FakeSerial]: b'MOTOR:left:100:right:100'
# [PicoMotor]: go_straight, speed=60
# [FakeSerial]: b'MOTOR:left:60:right:60'
# [PicoMotor]: go_straight, speed=20
# [PicoMotor]: Lowest speed is 50, reset value 20 to it.
# [FakeSerial]: b'MOTOR:left:50:right:50'
#
# ==== Test backward ====
# [PicoMotor]: go_straight, speed=-100
# [FakeSerial]: b'MOTOR:left:-100:right:-100'
# [PicoMotor]: go_straight, speed=-60
# [FakeSerial]: b'MOTOR:left:-60:right:-60'
# [PicoMotor]: go_straight, speed=-20
# [PicoMotor]: Lowest speed is 50, reset value -20 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-50'
#
# ==== Test left ====
# [PicoMotor]: turn_left, speed=100, diff=10
# [PicoMotor]: go_turn, speed=100, diff=-10
# [FakeSerial]: b'MOTOR:left:90:right:100'
# [PicoMotor]: turn_left, speed=60, diff=10
# [PicoMotor]: go_turn, speed=60, diff=-10
# [FakeSerial]: b'MOTOR:left:50:right:60'
# [PicoMotor]: turn_left, speed=60, diff=20
# [PicoMotor]: go_turn, speed=60, diff=-20
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [FakeSerial]: b'MOTOR:left:50:right:60'
# [PicoMotor]: turn_left, speed=50, diff=10
# [PicoMotor]: go_turn, speed=50, diff=-10
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [PicoMotor]: change to left_rotate
# [PicoMotor]: left_rotate
# [FakeSerial]: b'MOTOR:left:-50:right:50'
# [PicoMotor]: turn_left, speed=59, diff=10
# [PicoMotor]: go_turn, speed=59, diff=-10
# [PicoMotor]: Lowest speed is 50, reset value 49 to it.
# [PicoMotor]: change to left_rotate
# [PicoMotor]: left_rotate
# [FakeSerial]: b'MOTOR:left:-50:right:50'
# [PicoMotor]: turn_left, speed=30, diff=10
# [PicoMotor]: go_turn, speed=30, diff=-10
# [PicoMotor]: Lowest speed is 50, reset value 30 to it.
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [PicoMotor]: change to left_rotate
# [PicoMotor]: left_rotate
# [FakeSerial]: b'MOTOR:left:-50:right:50'
#
# ==== Test left ====
# [PicoMotor]: go_turn, speed=100, diff=-10
# [FakeSerial]: b'MOTOR:left:90:right:100'
# [PicoMotor]: go_turn, speed=60, diff=-10
# [FakeSerial]: b'MOTOR:left:50:right:60'
# [PicoMotor]: go_turn, speed=60, diff=-20
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [FakeSerial]: b'MOTOR:left:50:right:60'
# [PicoMotor]: go_turn, speed=50, diff=-10
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [PicoMotor]: change to left_rotate
# [PicoMotor]: left_rotate
# [FakeSerial]: b'MOTOR:left:-50:right:50'
# [PicoMotor]: go_turn, speed=59, diff=-10
# [PicoMotor]: Lowest speed is 50, reset value 49 to it.
# [PicoMotor]: change to left_rotate
# [PicoMotor]: left_rotate
# [FakeSerial]: b'MOTOR:left:-50:right:50'
# [PicoMotor]: go_turn, speed=30, diff=-10
# [PicoMotor]: Lowest speed is 50, reset value 30 to it.
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [PicoMotor]: change to left_rotate
# [PicoMotor]: left_rotate
# [FakeSerial]: b'MOTOR:left:-50:right:50'
#
# ==== Test right ====
# [PicoMotor]: turn_tight, speed=100, diff=10
# [PicoMotor]: go_turn, speed=100, diff=10
# [FakeSerial]: b'MOTOR:left:100:right:90'
# [PicoMotor]: turn_tight, speed=60, diff=10
# [PicoMotor]: go_turn, speed=60, diff=10
# [FakeSerial]: b'MOTOR:left:60:right:50'
# [PicoMotor]: turn_tight, speed=60, diff=20
# [PicoMotor]: go_turn, speed=60, diff=20
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [FakeSerial]: b'MOTOR:left:60:right:50'
# [PicoMotor]: turn_tight, speed=50, diff=10
# [PicoMotor]: go_turn, speed=50, diff=10
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: turn_tight, speed=59, diff=10
# [PicoMotor]: go_turn, speed=59, diff=10
# [PicoMotor]: Lowest speed is 50, reset value 49 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: turn_tight, speed=30, diff=10
# [PicoMotor]: go_turn, speed=30, diff=10
# [PicoMotor]: Lowest speed is 50, reset value 30 to it.
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
#
# ==== Test right ====
# [PicoMotor]: go_turn, speed=100, diff=10
# [FakeSerial]: b'MOTOR:left:100:right:90'
# [PicoMotor]: go_turn, speed=60, diff=10
# [FakeSerial]: b'MOTOR:left:60:right:50'
# [PicoMotor]: go_turn, speed=60, diff=20
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [FakeSerial]: b'MOTOR:left:60:right:50'
# [PicoMotor]: go_turn, speed=50, diff=10
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=59, diff=10
# [PicoMotor]: Lowest speed is 50, reset value 49 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=30, diff=10
# [PicoMotor]: Lowest speed is 50, reset value 30 to it.
# [PicoMotor]: Lowest speed is 50, reset value 40 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'

# %%
import ipywidgets.widgets as widgets
from IPython.display import display

speed_slider = widgets.IntSlider(description='speed', min=-100, max=100, step=1, orientation='vertical')
direct_slider = widgets.IntSlider(description='direct', min=-100, max=100, step=1, orientation='horizontal')

slider_container = widgets.HBox([speed_slider, direct_slider])
display(slider_container)
# Out:
# HBox(children=(IntSlider(value=0, description='speed', min=-100, orientation='vertical'), IntSlider(value=0, d…
# [PicoMotor]: go_straight, speed=-2
# [PicoMotor]: Lowest speed is 50, reset value -2 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-50'
# [PicoMotor]: go_straight, speed=-8
# [PicoMotor]: Lowest speed is 50, reset value -8 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-50'
# [PicoMotor]: go_straight, speed=-41
# [PicoMotor]: Lowest speed is 50, reset value -41 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-50'
# [PicoMotor]: go_straight, speed=-47
# [PicoMotor]: Lowest speed is 50, reset value -47 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-50'
# [PicoMotor]: go_straight, speed=-65
# [FakeSerial]: b'MOTOR:left:-65:right:-65'
# [PicoMotor]: go_straight, speed=-70
# [FakeSerial]: b'MOTOR:left:-70:right:-70'
# [PicoMotor]: go_straight, speed=-73
# [FakeSerial]: b'MOTOR:left:-73:right:-73'
# [PicoMotor]: go_straight, speed=-76
# [FakeSerial]: b'MOTOR:left:-76:right:-76'
# [PicoMotor]: go_straight, speed=-77
# [FakeSerial]: b'MOTOR:left:-77:right:-77'
# [PicoMotor]: go_straight, speed=-79
# [FakeSerial]: b'MOTOR:left:-79:right:-79'
# [PicoMotor]: go_straight, speed=-80
# [FakeSerial]: b'MOTOR:left:-80:right:-80'
# [PicoMotor]: go_straight, speed=-82
# [FakeSerial]: b'MOTOR:left:-82:right:-82'
# [PicoMotor]: go_straight, speed=-85
# [FakeSerial]: b'MOTOR:left:-85:right:-85'
# [PicoMotor]: go_straight, speed=-86
# [FakeSerial]: b'MOTOR:left:-86:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-8
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-86, diff=-17
# [FakeSerial]: b'MOTOR:left:-69:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-69
# [PicoMotor]: Lowest speed is 50, reset value -17 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-80
# [PicoMotor]: Lowest speed is 50, reset value -6 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value 14 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-97
# [PicoMotor]: Lowest speed is 50, reset value 11 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-95
# [PicoMotor]: Lowest speed is 50, reset value 9 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-90
# [PicoMotor]: Lowest speed is 50, reset value 4 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-81
# [PicoMotor]: Lowest speed is 50, reset value -5 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-77
# [PicoMotor]: Lowest speed is 50, reset value -9 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-68
# [PicoMotor]: Lowest speed is 50, reset value -18 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-61
# [PicoMotor]: Lowest speed is 50, reset value -25 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-56
# [PicoMotor]: Lowest speed is 50, reset value -30 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-52
# [PicoMotor]: Lowest speed is 50, reset value -34 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-50
# [PicoMotor]: Lowest speed is 50, reset value -36 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-47
# [PicoMotor]: Lowest speed is 50, reset value -39 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-45
# [PicoMotor]: Lowest speed is 50, reset value -41 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-43
# [PicoMotor]: Lowest speed is 50, reset value -43 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-41
# [PicoMotor]: Lowest speed is 50, reset value -45 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-38
# [PicoMotor]: Lowest speed is 50, reset value -48 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-29
# [FakeSerial]: b'MOTOR:left:-57:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-25
# [FakeSerial]: b'MOTOR:left:-61:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-23
# [FakeSerial]: b'MOTOR:left:-63:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-20
# [FakeSerial]: b'MOTOR:left:-66:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-18
# [FakeSerial]: b'MOTOR:left:-68:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-21
# [FakeSerial]: b'MOTOR:left:-65:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-23
# [FakeSerial]: b'MOTOR:left:-63:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-30
# [FakeSerial]: b'MOTOR:left:-56:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-44
# [PicoMotor]: Lowest speed is 50, reset value -42 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-55
# [PicoMotor]: Lowest speed is 50, reset value -31 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-64
# [PicoMotor]: Lowest speed is 50, reset value -22 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-80
# [PicoMotor]: Lowest speed is 50, reset value -6 to it.
# [FakeSerial]: b'MOTOR:left:-50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-89
# [PicoMotor]: Lowest speed is 50, reset value 3 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-93
# [PicoMotor]: Lowest speed is 50, reset value 7 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-98
# [PicoMotor]: Lowest speed is 50, reset value 12 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-86'
# [PicoMotor]: go_turn, speed=-86, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value 14 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-86'
# [PicoMotor]: go_turn, speed=-79, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value 21 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-79'
# [PicoMotor]: go_turn, speed=-78, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value 22 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-78'
# [PicoMotor]: go_turn, speed=-76, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value 24 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-76'
# [PicoMotor]: go_turn, speed=-73, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value 27 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-73'
# [PicoMotor]: go_turn, speed=-66, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value 34 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-66'
# [PicoMotor]: go_turn, speed=-61, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value 39 to it.
# [FakeSerial]: b'MOTOR:left:50:right:-61'
# [PicoMotor]: go_turn, speed=-55, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value 45 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-49, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -49 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-43, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -43 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-40, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -40 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-34, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -34 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-31, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -31 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-30, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -30 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-28, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -28 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-27, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -27 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-25, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -25 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-24, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -24 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-22, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -22 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-21, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -21 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'
# [PicoMotor]: go_turn, speed=-19, diff=-100
# [PicoMotor]: Lowest speed is 50, reset value -19 to it.
# [PicoMotor]: change to right_rotate
# [PicoMotor]: right_rotate
# [FakeSerial]: b'MOTOR:left:50:right:-50'

# %%
m = PicoMotor(serial_port)

def on_value_change(v):
    speed = speed_slider.value
    diff = direct_slider.value
    
    m.go(speed, diff)

speed_slider.observe(on_value_change, names='value')
direct_slider.observe(on_value_change, names='value')
